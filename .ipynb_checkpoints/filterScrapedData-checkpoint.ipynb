# %%
import glob
import pandas as pd
import numpy as np

# %%
filenames = glob.glob("csvs/*.csv")

# %% [markdown]
# ## Calibre

# %%
calibre = pd.read_csv(filenames[1])

# %%
aptsOfInterest = calibre[(~calibre['floorplan_name'].str.contains("Hampton")) & (calibre['rent_min'] < 1750)]
groupbyColumns = calibreAptsOfInterest.columns[:-3].tolist() + [calibreAptsOfInterest.columns[-1]] + [calibreAptsOfInterest.columns[-3]]
aptsOfInterest.groupby(groupbyColumns).agg(start_move_in_day=('move_in_day', 'min'), 
                                           end_move_in_day=('move_in_day', 'max'))
# Out:
#                                                                                                                              start_move_in_day  \
# scraping_date scraping_time floorplan_name      bedroom bathroom squareFootage rent_min rent_max move_in_year move_in_month
# 2022/05/20    12            Fillmore Classic II 1.0     1.0      1040.0        1640     1680     2022         5                             20
#
#                                                                                                                              end_move_in_day
# scraping_date scraping_time floorplan_name      bedroom bathroom squareFootage rent_min rent_max move_in_year move_in_month
# 2022/05/20    12            Fillmore Classic II 1.0     1.0      1040.0        1640     1680     2022         5                           30

# %% [markdown]
# ## Legacy

# %%
pd.read_csv(filenames[0])
# Out:
# Empty DataFrame
# Columns: [scraping_date, scraping_time, floorplan_name, bedroom, bathroom, squareFootage, rent_min, rent_max, move_in_month, move_in_day, move_in_year]
# Index: []

# %%
legacy
# Out:
# Empty DataFrame
# Columns: [scraping_date, scraping_time, floorplan_name, bedroom, bathroom, squareFootage, rent_min, rent_max, move_in_month, move_in_day, move_in_year]
# Index: []

# %% [markdown]
# ## Madison

# %%
madison = pd.read_csv(filenames[2])

# %%
madison[(madison['bedroom'] >= 2) & (madison['rent_min'] < 1750)]
# Out:
#    scraping_date  scraping_time floorplan_name  bedroom  bathroom  \
# 9     2022/05/20             12        Cypress        2         2
# 29    2022/05/20             12        Cypress        2         2
# 49    2022/05/20             12        Cypress        2         2
#
#     apartment_number  square_footage  rent_min  rent_max  move_in_month  \
# 9               2027             987      1708      2188              5
# 29              2027             987      1708      2188              5
# 49              2027             987      1708      2188              5
#
#     move_in_day  move_in_year
# 9            20          2022
# 29           20          2022
# 49           20          2022

# %%
legacy[legacy['move_in_year'].isnull()].index
# Out:
# Int64Index([  6,   7,  10,  18,  19,  22,  30,  31,  34,  42,
#             ...
#             752, 753, 754, 755, 756, 757, 758, 759, 760, 761],
#            dtype='int64', length=250)

# %%
legacy.head(10)
# Out:
#   scraping_date  scraping_time floorplan_name  bedroom  bathroom  \
# 0    2022/05/20             10             a3        1         1
# 1    2022/05/20             10           a3_e        1         1
# 2    2022/05/20             10           a3_p        1         1
# 3    2022/05/20             10           a2_p        1         1
# 4    2022/05/20             10         b1dh_e        2         1
# 5    2022/05/20             10           b1dh        2         1
# 6    2022/05/20             10           bt_e        2      1100
# 7    2022/05/20             10         b2dh_p        2      1000
# 8    2022/05/20             10             b3        2         2
# 9    2022/05/20             10             b5        2         2
#
#    squareFootage  rent_min  rent_max  move_in_month  move_in_day  move_in_year
# 0            800      1262      1765              5           20        2022.0
# 1            800      1276      1578              5           20        2022.0
# ...
